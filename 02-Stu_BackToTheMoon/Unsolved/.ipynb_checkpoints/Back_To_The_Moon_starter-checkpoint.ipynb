# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
import sklearn as skl
import tensorflow as tf
from sklearn.datasets import make_moons

# Creating dummy nonlinear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Creating a DataFrame to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons

# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_moons, y_moons, random_state=78)

# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a Keras Sequential model and add more than one Dense hidden layer
nn_model = tf.keras.models.Sequential()
# Check the structure of the Sequential model
# Add our first Dense layer, including the input layer WITH 5 NEURONS AS INPUT 
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))
# Add the Second Dense layer layer that uses a "relu"
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu"))
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 5)                 15
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 23
# Trainable params: 23
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model and train over more than 100 epochs
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Evaluate the performance of model using the loss and predictive accuracy of the model on the test dataset.
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6685 - accuracy: 0.7973
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6480 - accuracy: 0.8053
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6267 - accuracy: 0.8173
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6047 - accuracy: 0.8200
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5826 - accuracy: 0.8267
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5614 - accuracy: 0.8320
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5414 - accuracy: 0.8373
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5231 - accuracy: 0.8453
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5070 - accuracy: 0.8453
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4929 - accuracy: 0.8493
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4809 - accuracy: 0.8547
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4696 - accuracy: 0.8613
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.8653
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4517 - accuracy: 0.8653
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4436 - accuracy: 0.8707
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4365 - accuracy: 0.8747
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4301 - accuracy: 0.8747
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.8760
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4183 - accuracy: 0.8747
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8747
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4075 - accuracy: 0.8760
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4027 - accuracy: 0.8760
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8747
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3936 - accuracy: 0.8747
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8787
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8853
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3814 - accuracy: 0.8880
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3777 - accuracy: 0.8867
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3741 - accuracy: 0.8893
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3706 - accuracy: 0.8893
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3673 - accuracy: 0.8893
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8920
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3607 - accuracy: 0.8933
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3576 - accuracy: 0.8933
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.8960
# Epoch 36/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8973
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3487 - accuracy: 0.8987
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3460 - accuracy: 0.8973
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3430 - accuracy: 0.9000
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.8987
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.9013
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3349 - accuracy: 0.9000
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3325 - accuracy: 0.9013
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.9027
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3275 - accuracy: 0.9040
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3251 - accuracy: 0.9040
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3228 - accuracy: 0.9053
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3206 - accuracy: 0.9040
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3183 - accuracy: 0.9053
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3161 - accuracy: 0.9093
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3139 - accuracy: 0.9093
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3118 - accuracy: 0.9093
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3097 - accuracy: 0.9093
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3077 - accuracy: 0.9093
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3055 - accuracy: 0.9107
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3036 - accuracy: 0.9133
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3018 - accuracy: 0.9120
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2996 - accuracy: 0.9133
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2977 - accuracy: 0.9133
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2958 - accuracy: 0.9133
# Epoch 61/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2940 - accuracy: 0.9147
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.9147
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2903 - accuracy: 0.9147
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2886 - accuracy: 0.9147
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2868 - accuracy: 0.9133
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2847 - accuracy: 0.9133
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.9147
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.9133
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2794 - accuracy: 0.9133
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2776 - accuracy: 0.9133
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2759 - accuracy: 0.9147
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.9160
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.9173
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2702 - accuracy: 0.9173
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2683 - accuracy: 0.9187
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2664 - accuracy: 0.9187
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2644 - accuracy: 0.9187
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2625 - accuracy: 0.9200
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2603 - accuracy: 0.9200
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.9200
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2563 - accuracy: 0.9187
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2543 - accuracy: 0.9240
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.9240
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.9253
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2469 - accuracy: 0.9267
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2445 - accuracy: 0.9267
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2425 - accuracy: 0.9293
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9293
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2374 - accuracy: 0.9320
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.9333
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.9347
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2289 - accuracy: 0.9347
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2253 - accuracy: 0.9333
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.9373
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2166 - accuracy: 0.9387
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2121 - accuracy: 0.9413
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.9440
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2041 - accuracy: 0.9453
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.9493
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9493

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.1778 - accuracy: 0.9480
# Loss: 0.17783571779727936, Accuracy: 0.9480000138282776
