# %%
#%matplotlib
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=5000, centers=2, n_features=2, random_state=42, cluster_std=3)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=50)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()
# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 1)                 3
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1302 - accuracy: 0.9493
# Epoch 2/50
# 118/118 [==============================] - 0s 781us/step - loss: 0.1302 - accuracy: 0.9496
# Epoch 3/50
# 118/118 [==============================] - 0s 765us/step - loss: 0.1301 - accuracy: 0.9496
# Epoch 4/50
# 118/118 [==============================] - 0s 850us/step - loss: 0.1301 - accuracy: 0.9493
# Epoch 5/50
# 118/118 [==============================] - 0s 785us/step - loss: 0.1300 - accuracy: 0.9499
# Epoch 6/50
# 118/118 [==============================] - 0s 830us/step - loss: 0.1300 - accuracy: 0.9493
# Epoch 7/50
# 118/118 [==============================] - 0s 869us/step - loss: 0.1300 - accuracy: 0.9496
# Epoch 8/50
# 118/118 [==============================] - 0s 889us/step - loss: 0.1299 - accuracy: 0.9504
# Epoch 9/50
# 118/118 [==============================] - 0s 800us/step - loss: 0.1299 - accuracy: 0.9496
# Epoch 10/50
# 118/118 [==============================] - 0s 837us/step - loss: 0.1298 - accuracy: 0.9499
# Epoch 11/50
# 118/118 [==============================] - 0s 787us/step - loss: 0.1298 - accuracy: 0.9493
# Epoch 12/50
# 118/118 [==============================] - 0s 838us/step - loss: 0.1298 - accuracy: 0.9496
# Epoch 13/50
# 118/118 [==============================] - 0s 827us/step - loss: 0.1297 - accuracy: 0.9496
# Epoch 14/50
# 118/118 [==============================] - 0s 904us/step - loss: 0.1297 - accuracy: 0.9501
# Epoch 15/50
# 118/118 [==============================] - 0s 883us/step - loss: 0.1296 - accuracy: 0.9499
# Epoch 16/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1296 - accuracy: 0.9496
# Epoch 17/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1296 - accuracy: 0.9496
# Epoch 18/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9499
# Epoch 19/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9496
# Epoch 20/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1294 - accuracy: 0.9493
# Epoch 21/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1294 - accuracy: 0.9496
# Epoch 22/50
# 118/118 [==============================] - 0s 955us/step - loss: 0.1294 - accuracy: 0.9496
# Epoch 23/50
# 118/118 [==============================] - 0s 858us/step - loss: 0.1293 - accuracy: 0.9493
# Epoch 24/50
# 118/118 [==============================] - 0s 830us/step - loss: 0.1293 - accuracy: 0.9493
# Epoch 25/50
# 118/118 [==============================] - 0s 925us/step - loss: 0.1293 - accuracy: 0.9493
# Epoch 26/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1293 - accuracy: 0.9501
# Epoch 27/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1292 - accuracy: 0.9493
# Epoch 28/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1291 - accuracy: 0.9499
# Epoch 29/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1290 - accuracy: 0.9491
# Epoch 30/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1290 - accuracy: 0.9493
# Epoch 31/50
# 118/118 [==============================] - 0s 801us/step - loss: 0.1290 - accuracy: 0.9499
# Epoch 32/50
# 118/118 [==============================] - 0s 755us/step - loss: 0.1289 - accuracy: 0.9496
# Epoch 33/50
# 118/118 [==============================] - 0s 840us/step - loss: 0.1289 - accuracy: 0.9488
# Epoch 34/50
# 118/118 [==============================] - 0s 841us/step - loss: 0.1289 - accuracy: 0.9496
# Epoch 35/50
# 118/118 [==============================] - 0s 883us/step - loss: 0.1288 - accuracy: 0.9493
# Epoch 36/50
# 118/118 [==============================] - 0s 888us/step - loss: 0.1288 - accuracy: 0.9499
# Epoch 37/50
# 118/118 [==============================] - 0s 766us/step - loss: 0.1288 - accuracy: 0.9485
# Epoch 38/50
# 118/118 [==============================] - 0s 760us/step - loss: 0.1287 - accuracy: 0.9491
# Epoch 39/50
# 118/118 [==============================] - 0s 722us/step - loss: 0.1287 - accuracy: 0.9496
# Epoch 40/50
# 118/118 [==============================] - 0s 786us/step - loss: 0.1288 - accuracy: 0.9491
# Epoch 41/50
# 118/118 [==============================] - 0s 750us/step - loss: 0.1287 - accuracy: 0.9491
# Epoch 42/50
# 118/118 [==============================] - 0s 932us/step - loss: 0.1286 - accuracy: 0.9491
# Epoch 43/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1286 - accuracy: 0.9496
# Epoch 44/50
# 118/118 [==============================] - 0s 727us/step - loss: 0.1286 - accuracy: 0.9491
# Epoch 45/50
# 118/118 [==============================] - 0s 686us/step - loss: 0.1285 - accuracy: 0.9493
# Epoch 46/50
# 118/118 [==============================] - 0s 909us/step - loss: 0.1285 - accuracy: 0.9488
# Epoch 47/50
# 118/118 [==============================] - 0s 820us/step - loss: 0.1285 - accuracy: 0.9493
# Epoch 48/50
# 118/118 [==============================] - 0s 790us/step - loss: 0.1285 - accuracy: 0.9496
# Epoch 49/50
# 118/118 [==============================] - 0s 746us/step - loss: 0.1285 - accuracy: 0.9499
# Epoch 50/50
# 118/118 [==============================] - 0s 656us/step - loss: 0.1284 - accuracy: 0.9491

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 40/40 - 0s - loss: 0.1100 - accuracy: 0.9560
# Loss: 0.11001241207122803, Accuracy: 0.9559999704360962

# %%
# Create a DataFrame containing training history
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Plot the accuracy
# Out:
# <AxesSubplot:>
